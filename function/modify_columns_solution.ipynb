# %%
import pandas as pd

# %%
def modify_columns_solution(df: pd.DataFrame, column_to_drop, column_to_change):
   return df.assign(new = lambda x: x[column_to_change] + 1).drop(columns=[column_to_drop]).rename({column_to_change: 'renamed'})
